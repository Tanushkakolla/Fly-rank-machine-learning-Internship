# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
### My Lane

**Lane:** Content Refresh Prioritization (Lane 2)

**ML Task Type:** Ranking

**Why Ranking?**

The goal is to order webpages from highest to lowest refresh priority. Rather than making a simple yes-or-no decision, the model assigns a relative priority so the content team can update the most valuable pages first.
"""))
# Out:
# ### My Lane
#
# **Lane:** Content Refresh Prioritization (Lane 2)
#
# **ML Task Type:** Ranking
#
# **Why Ranking?**
#
# The goal is to order webpages from highest to lowest refresh priority. Rather than making a simple yes-or-no decision, the model assigns a relative priority so the content team can update the most valuable pages first.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
### Target / Proxy

**Target:**

Predict a refresh priority score for every webpage.

**Proxy:**

Since the dataset does not contain a direct priority label, existing performance signals such as declining trends are used as a proxy to estimate which pages are more likely to require updates.
"""))
# Out:
# ### Target / Proxy
#
# **Target:**
#
# Predict a refresh priority score for every webpage.
#
# **Proxy:**
#
# Since the dataset does not contain a direct priority label, existing performance signals such as declining trends are used as a proxy to estimate which pages are more likely to require updates.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
### Success Metric

**Primary Metric:** Precision@50

The objective is to ensure that the highest-ranked pages selected by the model are genuinely good candidates for a content refresh.

A higher Precision@50 means the content team spends time updating pages that are more likely to improve overall performance.
"""))
# Out:
# ### Success Metric
#
# **Primary Metric:** Precision@50
#
# The objective is to ensure that the highest-ranked pages selected by the model are genuinely good candidates for a content refresh.
#
# A higher Precision@50 means the content team spends time updating pages that are more likely to improve overall performance.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

# Load the starter dataset
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Dataset Shape:", df.shape)
print("\nOne row represents one webpage (content page).\n")

# Display a few important columns
df[[
    "content_id",
    "content_type",
    "clicks_90d",
    "impressions_90d",
    "ctr",
    "avg_position",
    "trend_direction"
]].head()
# Out:
# Dataset Shape: (30000, 44)
#
# One row represents one webpage (content page).
#              content_id     content_type  clicks_90d  impressions_90d   ctr  \
# 0  content_304f48230142  keyword article          29             3803  0.76
# 1  content_a1fb4e703a9e  keyword article           7            15320  0.05
# 2  content_9aa793d4d895  keyword article          11            12581  0.09
# 3  content_331d6c4de07b  keyword article          58            11751  0.49
# 4  content_d99b7a2d90ca  keyword article          24            19140  0.13
#
#    avg_position trend_direction
# 0          10.6            down
# 1          20.3            down
# 2          36.5            down
# 3           6.2          stable
# 4          44.0            down

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
reason = """
Using a fixed rule, such as refreshing every page after a certain number of days,
ignores important information like search performance, click-through rate,
traffic patterns, and content characteristics. A machine learning model can
combine all of these signals to produce a more accurate ranking of which pages
should be refreshed first.
"""

print(reason)
# Out:
# Using a fixed rule, such as refreshing every page after a certain number of days,
# ignores important information like search performance, click-through rate,
# traffic patterns, and content characteristics. A machine learning model can
# combine all of these signals to produce a more accurate ranking of which pages
# should be refreshed first.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
